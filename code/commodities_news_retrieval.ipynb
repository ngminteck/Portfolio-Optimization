# %%
import pandas as pd
from datetime import datetime, timezone
import os
import requests
import time
import random
from urllib.parse import quote

# %%
def convert_datetime(pub_date_str):
    # Step 1: Parse the datetime string
    pub_date = datetime.strptime(pub_date_str, "%Y-%m-%dT%H:%M:%SZ")

    # Step 2: Convert to UTC (if not already in UTC)
    pub_date_utc = pub_date.replace(tzinfo=timezone.utc)

    # Step 3: Format to only include the date
    pub_date_utc_only_date = datetime.strftime(pub_date_utc, "%Y-%m-%d")
    return pub_date_utc_only_date

# %%
def fetch_guardian_news_for_commodities(subjects, start_date, end_date, api_key):
    news_data = []
    titles_set = set()  # Set to keep track of titles
    for subject in subjects:
        base_url = "https://content.guardianapis.com/search?"
        page = 1
        page_size = 1
        start_date = pd.to_datetime(start_date).strftime("%Y-%m-%d")
        end_date = pd.to_datetime(end_date).strftime("%Y-%m-%d")
        while page <= page_size:
            time.sleep(random.uniform(1, 3))
            response = requests.get(base_url + f'page={page}&q={quote(subject)}&from-date={start_date}&api-key={api_key}&order-by=oldest')
            if response.status_code != 200:
                print(f"Error: {response.status_code}")
                break  # Exit if there's an error
        
            data = response.json()
            
            # Check if there are no results
            if not data['response']['results']:
                print("No more results found, exiting loop.")
                break  # Break out of the loop if no results are found
            
            page_size = data['response']['pages']
            print(f"Page size: {page_size}")
            
            for article in data['response']['results']:
                title = article['webTitle']
                pub_date = article['webPublicationDate']
                pub_date = convert_datetime(pub_date)
                if start_date <= pub_date <= end_date:
                    print(pub_date)
                    if title not in titles_set:
                        news_data.append({
                            'title': title,
                            'published_date': pub_date
                        })
                        titles_set.add(title)  # Add title to the set
                    else:
                        continue
                else:
                    page_size = page
                    print('Breaking out of loop for this subject...')
                    break  # Exit the loop if the article is outside the date range

            page += 1
    
    # Sort and save only if there's news data
    if news_data:
        sorted_data = sorted(news_data, key=lambda x: x['published_date'])
        df = pd.DataFrame(sorted_data)
        
        # Save DataFrame to a CSV file
        csv_filename = f'../data/news/{subjects[0]}.csv'
        df.to_csv(csv_filename, index=False)
        print(f"Data saved to {csv_filename}")
    else:
        print("No news data to save.")

    return news_data

# %%
# insert api key
api_key = ''
start_date = '2015-05-08 00:00:00+00:00'
end_date = '2021-06-29 00:00:00+00:00'

# change accordingly based on which commodities to retrieve news for
commods = ["Wheat"]
fetch_guardian_news_for_commodities(commods, start_date, end_date, api_key)
# Out:
# Page size: 328
# 2015-05-08
# 2015-05-10
# 2015-05-11
# 2015-05-12
# 2015-05-12
# 2015-05-13
# 2015-05-14
# 2015-05-17
# 2015-05-18
# 2015-05-19
# Page size: 328
# 2015-05-19
# 2015-05-20
# 2015-05-20
# 2015-05-22
# 2015-05-22
# 2015-05-22
# 2015-05-24
# 2015-05-25
# 2015-05-26
# 2015-05-26
# Page size: 328
# 2015-05-26
# 2015-05-29
# 2015-05-29
# 2015-05-30
# 2015-06-02
# 2015-06-04
# 2015-06-04
# 2015-06-05
# 2015-06-06
# 2015-06-06
# Page size: 328
# 2015-06-07
# 2015-06-07
# 2015-06-09
# 2015-06-09
# 2015-06-09
# 2015-06-10
# 2015-06-11
# 2015-06-11
# 2015-06-12
# 2015-06-12
# Page size: 328
# 2015-06-16
# 2015-06-17
# 2015-06-18
# 2015-06-19
# 2015-06-23
# 2015-06-24
# 2015-06-24
# 2015-06-25
# 2015-06-25
# 2015-06-25
# Page size: 328
# 2015-06-26
# 2015-06-26
# 2015-06-27
# 2015-06-27
# 2015-07-01
# 2015-07-03
# 2015-07-03
# 2015-07-05
# 2015-07-05
# 2015-07-06
# Error: 429
# Data saved to ../data/news/Wheat.csv
# [{'title': 'Lebanese leave-taking: Greg Malouf’s last meal',
#   'published_date': '2015-05-08'},
#  {'title': 'Media Monkey’s Election Diary: Kay Burley, Jeremy Paxman and Andrew Neil',
#   'published_date': '2015-05-10'},
#  {'title': 'Home business innovation 2014: Designed2Eat',
#   'published_date': '2015-05-11'},
#  {'title': "Indian land bill: 'We’re losing not just land, but a whole generation of farmers'",
#   'published_date': '2015-05-12'},
#  {'title': 'The Fiver | Totally irrelevant perambulations involving, perhaps, Nana Mouskouri',
#   'published_date': '2015-05-12'},
#  {'title': 'Lukewarmers – the third stage of climate denial, gambling on snake eyes | Dana Nuccitelli',
#   'published_date': '2015-05-13'},
#  {'title': 'Supermarket lagers: the best and worst – taste test',
#   'published_date': '2015-05-14'},
#  {'title': 'Peter Kennard: Unofficial War Artist review – the king of political montage',
#   'published_date': '2015-05-17'},
#  {'title': "You had me at 'vagina rejuvenation': my weird day out at an anti-ageing exhibition",
#   'published_date': '2015-05-18'},
#  {'title': 'Guardian Weekly letters, 22 May 2015',
#   'published_date': '2015-05-19'},
#  {'title': 'Mind the gap: why colleges have so many female leaders',
#   'published_date': '2015-05-19'},
#  {'title': 'The doomsday vault: the seeds that could save a post-apocalyptic world | Suzanne Goldenberg',
#   'published_date': '2015-05-20'},
#  {'title': 'The military spy turned sustainability warrior - drones have come of age',
#   'published_date': '2015-05-20'},
#  {'title': 'If Aboriginal people are forced off their land, who will pass down the stories? | Kelly Briggs',
#   'published_date': '2015-05-22'},
#  {'title': 'Ethiopia prepares for election with ruling party expecting landslide victory',
#   'published_date': '2015-05-22'},
#  {'title': 'Seeds of Time - preserving food resources in a hot future climate | John Abraham',
#   'published_date': '2015-05-22'},
#  {'title': 'Berber & Q: restaurant review | Jay Rayner',
#   'published_date': '2015-05-24'},
#  {'title': 'Poem of the week: The Sheaves by Edwin Arlington Robinson',
#   'published_date': '2015-05-25'},
#  {'title': "Refugees at Lebanon camp rely on 'hell water' that turns metal to rust | Peter Schwartzstein",
#   'published_date': '2015-05-26'},
#  {'title': 'Smarter working 2014: Designed2Eat',
#   'published_date': '2015-05-26'},
#  {'title': 'Guardian Weekly Letters, 29 May 2015',
#   'published_date': '2015-05-26'},
#  {'title': 'Destiny: House Of Wolves review', 'published_date': '2015-05-29'},
#  {'title': 'Iddu, London SW7 – restaurant review | Marina O’Loughlin',
#   'published_date': '2015-05-29'},
#  {'title': 'The heat and the death toll are rising in India. Is this a glimpse of Earth’s future?',
#   'published_date': '2015-05-30'},
#  {'title': 'The real northern powerhouses: the brass bands that moved me to tears',
#   'published_date': '2015-06-02'},
#  {'title': 'Bogus allergy tests causing real harm, say experts',
#   'published_date': '2015-06-04'},
#  {'title': 'Sprint to switch to wheat straw paper in two-month sustainability trial',
#   'published_date': '2015-06-04'},
#  {'title': 'Top 10 craft beer bars in Budapest',
#   'published_date': '2015-06-05'},
#  {'title': 'Best of the Sustainable Brands summit in San Diego',
#   'published_date': '2015-06-06'},
#  {'title': 'Yes, we are what we eat but let’s not be silly about it | Barbara Ellen',
#   'published_date': '2015-06-06'},
#  {'title': 'Driving through rural Australia proves the diversity of country and culture',
#   'published_date': '2015-06-07'},
#  {'title': 'Duck & Rice: restaurant review', 'published_date': '2015-06-07'},
#  {'title': "DeepMind: 'Artificial intelligence is a tool that humans can control and direct'",
#   'published_date': '2015-06-09'},
#  {'title': 'Guardian Weekly Letters, 12 June 2015',
#   'published_date': '2015-06-09'},
#  {'title': 'A distracting game of spot the fake: the Waddesdon Bequest – review',
#   'published_date': '2015-06-09'},
#  {'title': "Life in Mosul one year on: 'Isis with all its brutality is more honest than the Shia government'",
#   'published_date': '2015-06-10'},
#  {'title': 'Moldovan recipes flavoured with nostalgia | Cook residency',
#   'published_date': '2015-06-11'},
#  {'title': "Pakistan: 'Son, you brought electricity to the village and added 15 years to my life'",
#   'published_date': '2015-06-11'},
#  {'title': 'Decade of drought: a global tour of seven recent water crises',
#   'published_date': '2015-06-12'},
#  {'title': 'AFL: Port Adelaide v Geelong - liveblog | Russell Jackson',
#   'published_date': '2015-06-12'},
#  {'title': 'Guardian Weekly Letters, 19 June 2015',
#   'published_date': '2015-06-16'},
#  {'title': 'How fossil fuel emissions could take protein from the diets of the world’s poorest people | Graham Readfearn',
#   'published_date': '2015-06-17'},
#  {'title': 'How the Battle of Waterloo became a theatrical spectacular',
#   'published_date': '2015-06-18'},
#  {'title': 'Craft London, London SE10 – restaurant review | Marina O’Loughlin',
#   'published_date': '2015-06-19'},
#  {'title': 'Skivers and strivers: this 200–year–old myth won’t die | George Monbiot',
#   'published_date': '2015-06-23'},
#  {'title': 'Roads, railways and research can stop global food waste',
#   'published_date': '2015-06-24'},
#  {'title': "Will Greece go hungry if it exits the euro? That's a question for insurers",
#   'published_date': '2015-06-24'},
#  {'title': "My babushka's Uzbek duck and rice recipe | Cook residency",
#   'published_date': '2015-06-25'},
#  {'title': 'GM wheat no more pest-resistant than ordinary crops, trial shows',
#   'published_date': '2015-06-25'},
#  {'title': 'Paraguay deploys anti-narco top guns to combat economic need for weed | Laurence Blair',
#   'published_date': '2015-06-25'},
#  {'title': "Minimal sound and almost no fury: life in the shadow of Australia's windfarm 'hell'",
#   'published_date': '2015-06-26'},
#  {'title': "Green news roundup: Dutch court's climate ruling and hope for elephants",
#   'published_date': '2015-06-26'},
#  {'title': 'Green is the new black: the unstoppable rise of the healthy-eating guru',
#   'published_date': '2015-06-27'},
#  {'title': 'Slaves/Sleaford Mods/the Pop Group at Glastonbury 2015 review – a triple-bill of righteous anger',
#   'published_date': '2015-06-27'},
#  {'title': 'Meet the man who has trained more British journalists than anyone else',
#   'published_date': '2015-07-01'},
#  {'title': 'We need to grow 50% more food yet agriculture causes climate change. How do we get out of this bind?',
#   'published_date': '2015-07-03'},
#  {'title': 'Boost for dam-building and water storage in agriculture white paper',
#   'published_date': '2015-07-03'},
#  {'title': 'The foodie traveller … on the revival of Native American cuisine in Minneapolis',
#   'published_date': '2015-07-05'},
#  {'title': '‘It is like being inside a migraine’ – the first visitor to Grayson Perry’s House for Essex reveals all',
#   'published_date': '2015-07-05'},
#  {'title': "Barnaby Joyce's 'decadence' dog-whistle over same-sex marriage is pure desperation | Richard Ackland",
#   'published_date': '2015-07-06'}]
