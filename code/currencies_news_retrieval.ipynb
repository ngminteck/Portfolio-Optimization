# %%
import pandas as pd
from datetime import datetime, timezone
import os
import requests
import time
import random
from urllib.parse import quote

# %%
ticker_to_currency = {
    'SGD=X': 'Singapore Dollar',
    'SGDMYR=X': 'Singapore Dollar to Malaysian Ringgit',
    'GBPSGD=X': 'British Pound to Singapore Dollar',
    'EURSGD=X': 'Euro to Singapore Dollar',
    'SGDJPY=X': 'Singapore Dollar to Japanese Yen',
    'SGDHKD=X': 'Singapore Dollar to Hong Kong Dollar',
    'SGDIDR=X': 'Singapore Dollar to Indonesian Rupiah',
    'SGDCNY=X': 'Singapore Dollar to Chinese Yuan',
    'SGDTHB=X': 'Singapore Dollar to Thai Baht',
    'SGDINR=X': 'Singapore Dollar to Indian Rupee',
    'SGDKRW=X': 'Singapore Dollar to South Korean Won',
    'AUDSGD=X': 'Australian Dollar to Singapore Dollar',
    'NZDSGD=X': 'New Zealand Dollar to Singapore Dollar',
    'GBPUSD=X': 'British Pound to US Dollar',
    'JPY=X': 'Japanese Yen',
    'HKD=X': 'Hong Kong Dollar',
    'MYR=X': 'Malaysian Ringgit',
    'INR=X': 'Indian Rupee',
    'CNY=X': 'Chinese Yuan',
    'PHP=X': 'Philippine Peso',
    'IDR=X': 'Indonesian Rupiah',
    'THB=X': 'Thai Baht',
    'CHF=X': 'Swiss Franc',
    'MXN=X': 'Mexican Peso',
    'AUDUSD=X': 'Australian Dollar to US Dollar',
    'NZDUSD=X': 'New Zealand Dollar to US Dollar',
    'KRW=X': 'South Korean Won',
    'VND=X': 'Vietnamese Dong',
    'CAD=X': 'Canadian Dollar',
    'EURJPY=X': 'Euro to Japanese Yen',
    'GBPJPY=X': 'British Pound to Japanese Yen',
    'EURGBP=X': 'Euro to British Pound',
    'EURSEK=X': 'Euro to Swedish Krona',
    'EURCHF=X': 'Euro to Swiss Franc',
    'EURHUF=X': 'Euro to Hungarian Forint',
    # Add other tickers for rice_exporter_currencies as needed
    'CNYUSD=X': 'Chinese Yuan to US Dollar',
    'CNYKRW=X': 'Chinese Yuan to South Korean Won',
    'CNYJPY=X': 'Chinese Yuan to Japanese Yen',
    'EGP=X': 'Egyptian Pound',
    'TRY=X': 'Turkish Lira',
    'PGK=X': 'Papua New Guinean Kina',
    'IRR=X': 'Iranian Rial',
    'SAR=X': 'Saudi Riyal',
    'XAF=X': 'Central African CFA Franc',
    'BDT=X': 'Bangladeshi Taka',
    'INRAED=X': 'Indian Rupee to UAE Dirham',
    'NGR=X': 'Nigerian Naira',
    'NPR=X': 'Nepalese Rupee',
    'IDRPHP=X': 'Indonesian Rupiah to Philippine Peso',
    'IDRMYR=X': 'Indonesian Rupiah to Malaysian Ringgit',
    'IDRSGD=X': 'Indonesian Rupiah to Singapore Dollar',
    'MMK=X': 'Myanmar Kyat',
    'VNDPHP=X': 'Vietnamese Dong to Philippine Peso',
    'CNYVND=X': 'Chinese Yuan to Vietnamese Dong',
    'XOF=X': 'West African CFA Franc',
    'GHS=X': 'Ghanaian Cedi',
    'VNDMYR=X': 'Vietnamese Dong to Malaysian Ringgit',
    'IQD=X': 'Iraqi Dinar',
    'THBCNY=X': 'Thai Baht to Chinese Yuan',
    'THBZAR=X': 'Thai Baht to South African Rand',
    'THBHKD=X': 'Thai Baht to Hong Kong Dollar',
    'CNYMMK=X': 'Chinese Yuan to Myanmar Kyat',
    'EURMMK=X': 'Euro to Myanmar Kyat',
    'KHR=X': 'Cambodian Riel',
    'EUR=X': 'Euro',
    'MYR=X': 'Malaysian Ringgit',
    'PKR=X': 'Pakistani Rupee',
    'MYRPKR=X': 'Malaysian Ringgit to Pakistani Rupee',
    'KES=X': 'Kenyan Shilling',
    'PKRAED=X': 'Pakistani Rupee to UAE Dirham',
}

# %%
def get_ticker(currency_name, ticker_to_currency):
    for ticker, currency in ticker_to_currency.items():
        if currency_name in currency:
            return ticker
    return None

# %%
def convert_datetime(pub_date_str):
    # Step 1: Parse the datetime string
    pub_date = datetime.strptime(pub_date_str, "%Y-%m-%dT%H:%M:%SZ")

    # Step 2: Convert to UTC (if not already in UTC)
    pub_date_utc = pub_date.replace(tzinfo=timezone.utc)

    # Step 3: Format to only include the date
    pub_date_utc_only_date = datetime.strftime(pub_date_utc, "%Y-%m-%d")
    return pub_date_utc_only_date

# %%
def fetch_guardian_news_for_currencies(subjects, start_date, end_date, api_key, ticker_to_currency):
    news_data = []
    titles_set = set()  # Set to keep track of titles
    for subject in subjects:
        base_url = "https://content.guardianapis.com/search?"
        page = 1
        page_size = 1
        start_date = pd.to_datetime(start_date).strftime("%Y-%m-%d")
        end_date = pd.to_datetime(end_date).strftime("%Y-%m-%d")
        while page <= page_size:
            time.sleep(random.uniform(1, 3))
            response = requests.get(base_url + f'page={page}&q={quote(subject)}&from-date={start_date}&api-key={api_key}&order-by=oldest')
            if response.status_code != 200:
                print(f"Error: {response.status_code}")
                break  # Exit if there's an error
        
            data = response.json()
            
            # Check if there are no results
            if not data['response']['results']:
                print("No more results found, exiting loop.")
                break  # Break out of the loop if no results are found
            
            page_size = data['response']['pages']
            print(f"Page size: {page_size}")
            
            for article in data['response']['results']:
                title = article['webTitle']
                pub_date = article['webPublicationDate']
                pub_date = convert_datetime(pub_date)
                if start_date <= pub_date <= end_date:
                    print(pub_date)
                    if title not in titles_set:
                        news_data.append({
                            'title': title,
                            'published_date': pub_date
                        })
                        titles_set.add(title)  # Add title to the set
                    else:
                        continue
                else:
                    page_size = page
                    print('Breaking out of loop for this subject...')
                    break  # Exit the loop if the article is outside the date range

            page += 1
    
    # Sort and save only if there's news data
    if news_data:
        sorted_data = sorted(news_data, key=lambda x: x['published_date'])
        df = pd.DataFrame(sorted_data)
        
        # Save DataFrame to a CSV file
        ticker = get_ticker(subjects[0], ticker_to_currency)
        csv_filename = f'../data/news/{ticker}.csv'
        df.to_csv(csv_filename, index=False)
        print(f"Data saved to {csv_filename}")
    else:
        print("No news data to save.")

    return news_data

# %%
# insert api key
api_key = ''
start_date = '2014-01-03 00:00:00+00:00'
end_date = '2021-06-29 00:00:00+00:00'
# change ticker accordingly based on which currency to retrieve news for
ticker = ticker_to_currency['EURSGD=X']
fetch_guardian_news_for_currencies([ticker], start_date, end_date, api_key, ticker_to_currency)
# Out:
# Page size: 3627
# 2014-01-03
# 2014-01-03
# 2014-01-03
# 2014-01-03
# 2014-01-04
# 2014-01-04
# 2014-01-05
# 2014-01-05
# 2014-01-05
# 2014-01-06
# Page size: 3627
# 2014-01-06
# 2014-01-06
# 2014-01-06
# 2014-01-06
# 2014-01-06
# 2014-01-07
# 2014-01-07
# 2014-01-07
# 2014-01-07
# 2014-01-07
# Page size: 3627
# 2014-01-07
# 2014-01-07
# 2014-01-08
# 2014-01-08
# 2014-01-08
# 2014-01-08
# 2014-01-09
# 2014-01-09
# 2014-01-09
# 2014-01-09
# Page size: 3627
# 2014-01-09
# 2014-01-09
# 2014-01-09
# 2014-01-09
# 2014-01-09
# 2014-01-09
# 2014-01-09
# 2014-01-09
# 2014-01-10
# 2014-01-10
# Page size: 3627
# 2014-01-10
# 2014-01-10
# 2014-01-10
# 2014-01-10
# 2014-01-10
# 2014-01-10
# 2014-01-10
# 2014-01-10
# 2014-01-10
# 2014-01-10
# Page size: 3627
# 2014-01-12
# 2014-01-12
# 2014-01-12
# 2014-01-12
# 2014-01-12
# 2014-01-12
# 2014-01-12
# 2014-01-12
# 2014-01-12
# 2014-01-13
# Page size: 3627
# 2014-01-13
# 2014-01-13
# 2014-01-13
# 2014-01-13
# 2014-01-13
# 2014-01-13
# 2014-01-13
# 2014-01-14
# 2014-01-14
# 2014-01-14
# Page size: 3627
# 2014-01-14
# 2014-01-14
# 2014-01-14
# 2014-01-14
# 2014-01-14
# 2014-01-14
# 2014-01-14
# 2014-01-14
# 2014-01-14
# 2014-01-14
# Page size: 3627
# 2014-01-14
# 2014-01-14
# 2014-01-15
# 2014-01-15
# 2014-01-15
# 2014-01-15
# 2014-01-15
# 2014-01-15
# 2014-01-15
# 2014-01-15
# Page size: 3627
# 2014-01-15
# 2014-01-15
# 2014-01-15
# 2014-01-15
# 2014-01-16
# 2014-01-16
# 2014-01-16
# 2014-01-16
# 2014-01-16
# 2014-01-16
# Page size: 3627
# 2014-01-17
# 2014-01-17
# 2014-01-17
# 2014-01-17
# 2014-01-17
# 2014-01-17
# 2014-01-17
# 2014-01-17
# 2014-01-17
# 2014-01-17
# Page size: 3627
# 2014-01-17
# 2014-01-17
# 2014-01-18
# 2014-01-18
# 2014-01-18
# 2014-01-18
# 2014-01-18
# 2014-01-18
# 2014-01-19
# 2014-01-19
# Page size: 3627
# 2014-01-19
# 2014-01-19
# 2014-01-19
# 2014-01-19
# 2014-01-19
# 2014-01-19
# 2014-01-19
# 2014-01-20
# 2014-01-20
# 2014-01-20
# Page size: 3627
# 2014-01-20
# 2014-01-20
# 2014-01-20
# 2014-01-20
# 2014-01-20
# 2014-01-20
# 2014-01-21
# 2014-01-21
# 2014-01-21
# 2014-01-21
# Page size: 3627
# 2014-01-21
# 2014-01-21
# 2014-01-21
# 2014-01-21
# 2014-01-21
# 2014-01-21
# 2014-01-21
# 2014-01-21
# 2014-01-21
# 2014-01-21
# Page size: 3627
# 2014-01-22
# 2014-01-22
# 2014-01-22
# 2014-01-22
# 2014-01-22
# 2014-01-22
# 2014-01-23
# 2014-01-23
# 2014-01-23
# 2014-01-23
# Page size: 3627
# 2014-01-23
# 2014-01-23
# 2014-01-23
# 2014-01-23
# 2014-01-23
# 2014-01-24
# 2014-01-24
# 2014-01-24
# 2014-01-24
# 2014-01-24
# Page size: 3627
# 2014-01-24
# 2014-01-24
# 2014-01-24
# 2014-01-24
# 2014-01-24
# 2014-01-24
# 2014-01-24
# 2014-01-25
# 2014-01-25
# 2014-01-25
# Page size: 3627
# 2014-01-25
# 2014-01-26
# 2014-01-26
# 2014-01-26
# 2014-01-26
# 2014-01-27
# 2014-01-27
# 2014-01-27
# 2014-01-27
# 2014-01-27
# Error: 429
# Data saved to ../data/news/EURSGD=X.csv
# [{'title': 'Hery Rajaonarimampianina and the global leaders with the longest names',
#   'published_date': '2014-01-03'},
#  {'title': 'The US should encourage Arabic language students, not criminalise them | Anna Lekas Miller',
#   'published_date': '2014-01-03'},
#  {'title': 'Activate Singapore TV spot', 'published_date': '2014-01-03'},
#  {'title': 'Holiday hotspots: where to go in 2014',
#   'published_date': '2014-01-03'},
#  {'title': "Dad's tattoos are a map of his life",
#   'published_date': '2014-01-04'},
#  {'title': "José Mourinho urges English coaches to follow Steve McClaren's example",
#   'published_date': '2014-01-04'},
#  {'title': "A lost year for new technology? Look beyond 2013's gadgets",
#   'published_date': '2014-01-05'},
#  {'title': 'A-League: what we learned in round 13',
#   'published_date': '2014-01-05'},
#  {'title': "LearnVest CEO: 'Financial literacy is a fundamental human right'",
#   'published_date': '2014-01-05'},
#  {'title': 'Bill Gates preaches the aid gospel, but is he just a hypocrite? | Ian Birrell',
#   'published_date': '2014-01-06'},
#  {'title': 'How We Invented Freedom by Daniel Hannan; Acts of Union by Linda Colley – review',
#   'published_date': '2014-01-06'},
#  {'title': 'Malaysian central bank warns against Bitcoin',
#   'published_date': '2014-01-06'},
#  {'title': "All eyes on New York Mayor Bill de Blasio, America's leading progressive | Dean Baker",
#   'published_date': '2014-01-06'},
#  {'title': 'How US cities woke up to urban wildlife',
#   'published_date': '2014-01-06'},
#  {'title': 'Arsenal and England share pain with Theo Walcott after cruel blow',
#   'published_date': '2014-01-06'},
#  {'title': 'The future of the voluntary sector: the United Way case study',
#   'published_date': '2014-01-07'},
#  {'title': 'Cruciate ligament injury rules Theo Walcott out of World Cup 2014',
#   'published_date': '2014-01-07'},
#  {'title': "The GOP couldn't be more wrong about cutting unemployment insurance | Heidi Moore",
#   'published_date': '2014-01-07'},
#  {'title': 'Guardian Weekly Letters, 10 January 2014',
#   'published_date': '2014-01-07'},
#  {'title': 'England continues to pay the price of playing through the winter | James Riach',
#   'published_date': '2014-01-07'},
#  {'title': 'British Airways owner IAG leads FTSE higher on passenger figures',
#   'published_date': '2014-01-07'},
#  {'title': 'UK car sales hit pre-crisis levels; MPs grill FCA over Co-op bank - as it happened',
#   'published_date': '2014-01-07'},
#  {'title': "Government's flagship benefits scheme faces more delays after rift",
#   'published_date': '2014-01-08'},
#  {'title': 'This is the year of make or break for Europe | John Palmer',
#   'published_date': '2014-01-08'},
#  {'title': 'US private sector job creation jumps; Eurozone jobless at record high - as it happened',
#   'published_date': '2014-01-08'},
#  {'title': "China's Ming dynasty golden age to be star of British Museum blockbuster",
#   'published_date': '2014-01-08'},
#  {'title': 'Liberal MP attacks colleagues for not fighting to save fruit processing jobs',
#   'published_date': '2014-01-09'},
#  {'title': "The forgotten story of … Dallas Tornado's 1967-68 world tour | Neil Jones",
#   'published_date': '2014-01-09'},
#  {'title': "Outkast's musical chemistry is forever, ever",
#   'published_date': '2014-01-09'},
#  {'title': 'Standard Chartered: shock departure of finance director Richard Meddings',
#   'published_date': '2014-01-09'},
#  {'title': 'The Vaughn identity: Vince needs to return to his roots',
#   'published_date': '2014-01-09'},
#  {'title': 'Natural resources and sensible leaders bring high hopes for Indonesia',
#   'published_date': '2014-01-09'},
#  {'title': "How the 'value trap' squeezes Windows PC makers' revenues and profits",
#   'published_date': '2014-01-09'},
#  {'title': "Draghi warns eurozone crisis isn't over; Christmas gloom for Tesco and Morrisons - as it happened",
#   'published_date': '2014-01-09'},
#  {'title': 'Shia LaBeouf: the most messed-up former Disney star de nos jours',
#   'published_date': '2014-01-09'},
#  {'title': 'Euro plummets after ECB warns currency zone may need more support',
#   'published_date': '2014-01-09'},
#  {'title': 'Aluminium firm Alcoa to pay $384m after guilty plea in US over Bahrain bribes',
#   'published_date': '2014-01-09'},
#  {'title': 'The Railway Man – review | Peter Bradshaw',
#   'published_date': '2014-01-09'},
#  {'title': "Boot up: yes to 4K!, Mulally's red light, Watson's big question, and more",
#   'published_date': '2014-01-10'},
#  {'title': "Uncle the elephant joins brave march of children's classics back into print",
#   'published_date': '2014-01-10'},
#  {'title': 'Education wars: what the curriculum actually says about Australian history',
#   'published_date': '2014-01-10'},
#  {'title': "UN's Haoliang Xu joins global leadership debate at Guardian's Activate Singapore",
#   'published_date': '2014-01-10'},
#  {'title': 'Miners lifted by Chinese trade data but Fresnillo falls after Barclays downgrade',
#   'published_date': '2014-01-10'},
#  {'title': 'Race for England World Cup places starts for Townsend, Sterling et al | Michael Cox',
#   'published_date': '2014-01-10'},
#  {'title': 'Cryptocurrency: which musicians should coin their own cash?',
#   'published_date': '2014-01-10'},
#  {'title': "Landlords 'may turn away people on benefits when universal credit comes in'",
#   'published_date': '2014-01-10'},
#  {'title': "An MBE for hairdressing? Why not – but the honours system really won't do | Ian Jack",
#   'published_date': '2014-01-10'},
#  {'title': 'US economy created just 74,000 new jobs in December; unemployment rate drops to 6.7% - as it happened',
#   'published_date': '2014-01-10'},
#  {'title': "Cameron's EU referendum 'timebomb' could undermine UK position, say lords",
#   'published_date': '2014-01-10'},
#  {'title': 'The euro: from crisis to complacency | Editorial',
#   'published_date': '2014-01-10'},
#  {'title': 'Mario Draghi needs a new trick to help the euro recover: quantitative easing',
#   'published_date': '2014-01-12'},
#  {'title': 'Bank bonuses: brace yourself for the great Wall Street trousering',
#   'published_date': '2014-01-12'},
#  {'title': 'Labour says new licensing plan will improve status of teachers',
#   'published_date': '2014-01-12'},
#  {'title': "Newcastle's leading tech startups",
#   'published_date': '2014-01-12'},
#  {'title': 'What scientific idea is ready for retirement?',
#   'published_date': '2014-01-12'},
#  {'title': 'How to avoid becoming a sheep of Wall Street – and getting fleeced',
#   'published_date': '2014-01-12'},
#  {'title': "Does The Wolf of Wall Street glorify Jordan Belfort's immoral lifestyle?",
#   'published_date': '2014-01-12'},
#  {'title': 'A-League: what we learned this weekend',
#   'published_date': '2014-01-12'},
#  {'title': 'Ashley Cole faces life in the slow lane as demands of the job intensify | Sean Ingle',
#   'published_date': '2014-01-12'},
#  {'title': 'Minimum wage fear and loathing not based on evidence',
#   'published_date': '2014-01-13'},
#  {'title': 'Is your friend an unpaid branding enthusiast? | Peter Ormerod',
#   'published_date': '2014-01-13'},
#  {'title': 'Amec gains ground on planned £1.9bn deal, while Morrisons climbs on property talk',
#   'published_date': '2014-01-13'},
#  {'title': "Will Ghana's Hope City join Africa's herd of white elephant projects? | Mark Tran",
#   'published_date': '2014-01-13'},
#  {'title': 'Airbus claims to have overtaken rival Boeing after record sales in 2013',
#   'published_date': '2014-01-13'},
#  {'title': "Paul Dempsey: 'Media companies must embrace the open internet to survive'",
#   'published_date': '2014-01-13'},
#  {'title': 'Morrisons jumps on talk of property sales, helping push FTSE 100 higher',
#   'published_date': '2014-01-13'},
#  {'title': "Japan's Suntory buys Beam;  markets shrug off Friday's weak US jobs data - as it hapened",
#   'published_date': '2014-01-13'},
#  {'title': 'Man who pulled plug on Holden says politicians were not to blame',
#   'published_date': '2014-01-14'},
#  {'title': 'Universities are still best place to train teachers, report says',
#   'published_date': '2014-01-14'},
#  {'title': 'Three Rabobank traders charged in US with five-year plot to fix Libor',
#   'published_date': '2014-01-14'},
#  {'title': 'Boot up: Cyanogenmod speaks, Nest on privacy, 3D printing trends, and more',
#   'published_date': '2014-01-14'},
#  {'title': "Ballon d'Or: Ronaldo rewarded for making miraculous mundane",
#   'published_date': '2014-01-14'},
#  {'title': "A Somali refugee in Italy: 'There's a feeling of total disorientation'",
#   'published_date': '2014-01-14'},
#  {'title': "Startup Institute: 'We want to help people find careers they love'",
#   'published_date': '2014-01-14'},
#  {'title': 'Moving up or selling out? Musicians and brands are a heady cocktail',
#   'published_date': '2014-01-14'},
#  {'title': 'Top 10 science and tech books for January: Nazis, noises and cosmic sights',
#   'published_date': '2014-01-14'},
#  {'title': 'Paul Ryan and Kirsten Gillibrand push for action on poverty to aid US economy',
#   'published_date': '2014-01-14'},
#  {'title': "Manchester United's share price mirrors form under David Moyes | Owen Gibson",
#   'published_date': '2014-01-14'},
#  {'title': "Hollande's private life is the\xa0least of his problems | Simon Jenkins",
#   'published_date': '2014-01-14'},
#  {'title': 'School curriculum review panellist Kevin Donnelly hits back at critics',
#   'published_date': '2014-01-14'},
#  {'title': 'FA Cup third round replays – as they happened',
#   'published_date': '2014-01-14'},
#  {'title': 'François Hollande: private lives, public spending | Editorial',
#   'published_date': '2014-01-14'},
#  {'title': "Developing countries could be 'starved' of capital as financial stimulus ends",
#   'published_date': '2014-01-15'},
#  {'title': 'Underpaid intellectually disabled workers granted compensation fund',
#   'published_date': '2014-01-15'},
#  {'title': 'To tackle inequality, the first priority is to fight climate change',
#   'published_date': '2014-01-15'},
#  {'title': 'Reform EU or Britain quits - George Osborne lays down ultimatum',
#   'published_date': '2014-01-15'},
#  {'title': "Fifa transparency in Ballon d'Or votes should extend to World Cup bids | Marina Hyde",
#   'published_date': '2014-01-15'},
#  {'title': "George Osborne: don't make UK choose between joining euro or leaving EU",
#   'published_date': '2014-01-15'},
#  {'title': "Protection for London's banks at heart of UK's EU reform plans, says Osborne",
#   'published_date': '2014-01-15'},
#  {'title': 'Cameron and Miliband at PMQs: Politics live blog',
#   'published_date': '2014-01-15'},
#  {'title': 'My best citizenship lesson: using paper blogs to teach international digital citizens',
#   'published_date': '2014-01-15'},
#  {'title': 'False positive pregnancy tests: for sale on the internet',
#   'published_date': '2014-01-15'},
#  {'title': 'Bank of England governor Mark Carney criticises bonus caps and bank break-up - as it happened',
#   'published_date': '2014-01-15'},
#  {'title': "House prices: who's to blame for driving them through the roof?",
#   'published_date': '2014-01-15'},
#  {'title': 'Labour would change law to improve police diversity, says Yvette Cooper',
#   'published_date': '2014-01-16'},
#  {'title': 'Songs of despair: artists who give voice to the angst of our unsustainable lives',
#   'published_date': '2014-01-16'},
#  {'title': 'High-stakes climate poker | James M Byrne',
#   'published_date': '2014-01-16'},
#  {'title': 'Nick Clegg hosts his LBC phone-in: Politics live blog',
#   'published_date': '2014-01-16'},
#  {'title': "We live in anxious times, so let's talk about it | Daisy Buchanan",
#   'published_date': '2014-01-16'},
#  {'title': "Chile's Dakar Rally criticised by greens, archaeologists and indigenous groups",
#   'published_date': '2014-01-16'},
#  {'title': 'Student visa applications rise strongly after tough three years',
#   'published_date': '2014-01-17'},
#  {'title': 'Forty years of the Diane von Furstenberg wrap dress',
#   'published_date': '2014-01-17'},
#  {'title': 'Premier League: 10 things to look out for this weekend | Toby Moses',
#   'published_date': '2014-01-17'},
#  {'title': 'Australia v England – as it happened | Second ODI',
#   'published_date': '2014-01-17'},
#  {'title': 'A spy movie in need of shadows: the blunt force reboot of Jack Ryan',
#   'published_date': '2014-01-17'},
#  {'title': 'UK planning expert: there is something wrong with Britain',
#   'published_date': '2014-01-17'},
#  {'title': "Shell's profit warning linked to cost of drilling in Arctic waters",
#   'published_date': '2014-01-17'},
#  {'title': 'William Hague: independence would see Scotland lose billions in EU funding',
#   'published_date': '2014-01-17'},
#  {'title': "India's Winter Games hopefuls dogged by funding and official indifference",
#   'published_date': '2014-01-17'},
#  {'title': 'Pussy Riot members dedicate award nomination to Russian government - video',
#   'published_date': '2014-01-17'},
#  {'title': 'Retail sales grow at fastest rate for nine years - as it happened',
#   'published_date': '2014-01-17'},
#  {'title': 'Why brands should focus on social change, not philanthropy',
#   'published_date': '2014-01-17'},
#  {'title': 'Chang-rae Lee: \'When people asked, I\'d say, "I\'m writing a very strange book." I thought no one was going to get it\'',
#   'published_date': '2014-01-18'},
#  {'title': 'Hi-tech rivals San Francisco and Seattle clash on the road to Super Bowl 2014',
#   'published_date': '2014-01-18'},
#  {'title': 'Mike Leigh: actors and Mr Kipling cakes',
#   'published_date': '2014-01-18'},
#  {'title': 'The internet revolution versus the House of Lords | Henry Porter',
#   'published_date': '2014-01-18'},
#  {'title': "Nick Clegg's former aide quits Lib Dems with attack on handling of Rennard row",
#   'published_date': '2014-01-18'},
#  {'title': 'Nigel Farage becomes popular in Greece after outburst against the PM',
#   'published_date': '2014-01-18'},
#  {'title': 'Gender inequality: the unjust gulf between men and women | Observer editorial',
#   'published_date': '2014-01-19'},
#  {'title': 'The Redux Project', 'published_date': '2014-01-19'},
#  {'title': 'Café Football: restaurant review', 'published_date': '2014-01-19'},
#  {'title': 'Australia v England: third ODI – live! | Russell Jackson and John Ashdown',
#   'published_date': '2014-01-19'},
#  {'title': 'Living on $2.13 an hour and tips: the harsh inequality of the service industry',
#   'published_date': '2014-01-19'},
#  {'title': 'Swansea City v Tottenham Hotspur – as it happened | Daniel Harris',
#   'published_date': '2014-01-19'},
#  {'title': "Cardiff in contention to replace Dubai as ICC's administrative base",
#   'published_date': '2014-01-19'},
#  {'title': "Bribe-free and gay-friendly: Vladimir Putin's version of the Sochi Olympics",
#   'published_date': '2014-01-19'},
#  {'title': 'Davos debates income inequality but still invites tax avoiders',
#   'published_date': '2014-01-19'},
#  {'title': 'Neon cross project seeks funds for prayer place in outback',
#   'published_date': '2014-01-20'},
#  {'title': "Voluntary guidelines to protect young fashion models aren't working",
#   'published_date': '2014-01-20'},
#  {'title': "How do you solve a problem like Korea's dysfunctional housing market?",
#   'published_date': '2014-01-20'},
#  {'title': 'David Cameron is right: the last 10 minutes of Shrek 2 is cinematic genius',
#   'published_date': '2014-01-20'},
#  {'title': "It's bobsleigh time: Jamaican team raises $25,000 in Dogecoin",
#   'published_date': '2014-01-20'},
#  {'title': 'Rosetta comet-chasing spacecraft wakes up – as it happened',
#   'published_date': '2014-01-20'},
#  {'title': 'Labour: Tory MEPs failing to stand up to big business and vested interests',
#   'published_date': '2014-01-20'},
#  {'title': "US hails 'unprecedented opportunity' as Iran halts enriching high-level uranium",
#   'published_date': '2014-01-20'},
#  {'title': 'Stuart Lancaster: England must replicate Euro 96 mood to win World Cup',
#   'published_date': '2014-01-20'},
#  {'title': 'New, privatized African city heralds climate apartheid',
#   'published_date': '2014-01-21'},
#  {'title': "Adelaide bar's attack on penalty rates for staff sparks social media backlash",
#   'published_date': '2014-01-21'},
#  {'title': 'Co-op Bank crisis: what next for the co-operative sector?',
#   'published_date': '2014-01-21'},
#  {'title': 'Boot up: privacy measured, Beats tunes in, Yahoo as Detroit, and more',
#   'published_date': '2014-01-21'},
#  {'title': 'From Snapchat to Twitter: five biggest technology bust-ups',
#   'published_date': '2014-01-21'},
#  {'title': "The modern day 'starving artist' is likely on food stamps | Amien Essif",
#   'published_date': '2014-01-21'},
#  {'title': 'IMF: world economic recovery picking up pace but still weak and uneven',
#   'published_date': '2014-01-21'},
#  {'title': 'Costa short story award finalists revealed',
#   'published_date': '2014-01-21'},
#  {'title': 'How to raise money for a cause without losing your friends',
#   'published_date': '2014-01-21'},
#  {'title': 'Vatican prelate accused of money laundering',
#   'published_date': '2014-01-21'},
#  {'title': 'Canadian company behind bike-sharing programs seeks bankruptcy protection',
#   'published_date': '2014-01-21'},
#  {'title': 'Davos 2014: Pope Francis urges leaders to fight inequality; Matt Damon calls for clean water fight',
#   'published_date': '2014-01-21'},
#  {'title': "Renée Fleming: the Super Bowl's unlikely opera singing superstar",
#   'published_date': '2014-01-21'},
#  {'title': 'Welfare overhaul: even the experienced and educated are vulnerable',
#   'published_date': '2014-01-21'},
#  {'title': 'Interest rate rises will hit British households hard, say economists',
#   'published_date': '2014-01-22'},
#  {'title': 'At Davos, the west must help us root out corruption in Africa | Alpha Condé',
#   'published_date': '2014-01-22'},
#  {'title': "Wanted: a 'clean trillion' dollar investment to limit climate change",
#   'published_date': '2014-01-22'},
#  {'title': 'Davos 2014: World Economic Forum - day one as it happened',
#   'published_date': '2014-01-22'},
#  {'title': 'Heineken Cup 2013-14: highs and lows from the European club competition | Robert Kitson',
#   'published_date': '2014-01-22'},
#  {'title': 'Chinese oil giants make use of offshore shell companies in Caribbean',
#   'published_date': '2014-01-22'},
#  {'title': 'British banker receives death threats for anti-Singapore diatribe',
#   'published_date': '2014-01-23'},
#  {'title': 'Boob deodorant – the latest joke from the beauty industry | Jill Filipovic',
#   'published_date': '2014-01-23'},
#  {'title': "'Daddy, who are all these poor people?' How Anton Casey's Facebook comments dissed Singapore",
#   'published_date': '2014-01-23'},
#  {'title': "The bug of Wall Street: fools' gold",
#   'published_date': '2014-01-23'},
#  {'title': 'London and Paris: we could soon be part of the same conurbation | Anne Hidalgo',
#   'published_date': '2014-01-23'},
#  {'title': 'Counterfeiter with perfectionist streak arrested in Spain',
#   'published_date': '2014-01-23'},
#  {'title': "The Fiver | Sit back and wait until … wah! It's an emergency! | Scott Murray",
#   'published_date': '2014-01-23'},
#  {'title': 'Davos 2014: World Economic Forum - Day Two as it happened',
#   'published_date': '2014-01-23'},
#  {'title': 'Arild Andersen/Paolo Vinaccia/Tommy Smith: Mira – review',
#   'published_date': '2014-01-23'},
#  {'title': "Davos 2014: Larry Summers attacks George Osborne's austerity programme",
#   'published_date': '2014-01-24'},
#  {'title': 'Argentinian peso: a sting in the tail or the start of a new crisis? | Larry Elliott',
#   'published_date': '2014-01-24'},
#  {'title': "Ericsson's Arun Bansal on how the networked society is enabling change",
#   'published_date': '2014-01-24'},
#  {'title': "Argentina, the peso and the 'blue dollar': what tourists need to know",
#   'published_date': '2014-01-24'},
#  {'title': 'Eyewitness: Singapore and Switzerland',
#   'published_date': '2014-01-24'},
#  {'title': 'Emerging market chaos hits stock markets and currencies',
#   'published_date': '2014-01-24'},
#  {'title': 'Peso collapse raises fears Argentina lurching towards decennial crisis',
#   'published_date': '2014-01-24'},
#  {'title': "America's UK bases way past their sell-by date | @guardianletters",
#   'published_date': '2014-01-24'},
#  {'title': 'Leonard Barden on Chess', 'published_date': '2014-01-24'},
#  {'title': "Norway men's curling team take early gold for dodgy fashion sense",
#   'published_date': '2014-01-24'},
#  {'title': 'Unthinkable? Justin and Miley | Editorial',
#   'published_date': '2014-01-24'},
#  {'title': 'Davos 2014: climate change and sustainability – day three as it happened',
#   'published_date': '2014-01-24'},
#  {'title': 'West Ham sign Serie A duo Antonio Nocerino and Marco Borriello',
#   'published_date': '2014-01-25'},
#  {'title': 'Davos 2014: World Economic Forum – day four  as it happened',
#   'published_date': '2014-01-25'},
#  {'title': "San Francisco's guerrilla protest at Google buses swells into revolt",
#   'published_date': '2014-01-25'},
#  {'title': "Michel Platini's Euro 2016 qualification brainwave lacks common sense | Daniel Taylor",
#   'published_date': '2014-01-25'},
#  {'title': 'All three main parties are jittery. Which one can hold its nerve? | Andrew Rawnsley',
#   'published_date': '2014-01-26'},
#  {'title': 'Police name Maryland mall gunman in shooting which left three dead',
#   'published_date': '2014-01-26'},
#  {'title': 'Chelsea v Stoke City – as it happened! | Ian McCourt',
#   'published_date': '2014-01-26'},
#  {'title': "The truth about David Cameron's fracking fairytale | Chris Huhne",
#   'published_date': '2014-01-26'},
#  {'title': 'Australia, the steroid-soaked neighbourhood bully of the Pacific | Jeff Sparrow',
#   'published_date': '2014-01-27'},
#  {'title': 'Mixed messages on interest rates as the Reserve Bank considers its next move',
#   'published_date': '2014-01-27'},
#  {'title': 'Banda Aceh: where community spirit has gone but peace has lasted',
#   'published_date': '2014-01-27'},
#  {'title': 'New Orleans: houses can be rebuilt, but can trust in central government?',
#   'published_date': '2014-01-27'},
#  {'title': "Mozilla's Li Gong on the problems of the mobile web",
#   'published_date': '2014-01-27'}]
